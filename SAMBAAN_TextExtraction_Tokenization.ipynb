# %% [markdown]
# # Jezzrel Aladdin S. Sambaan
# # BSIT-4R5

# %% [markdown]
# 1. Display the sample content of your page (10 pts)
# 2. Use the Split function to get the number of words (10 pts)
# 3. Use the Split function to get the number of sentences (10 pts)
# 4. Use NLTK framework to get the number of words (10 pts)
# 5. Use NLTK framework to get the number of sentences (10 pts)

# %%
# !pip install pdfplumber
# uncomment line above if keras and tensorflow is not installed on your machine/colab

# %%
# import the required libraries
import pdfplumber
import nltk
import re
import string
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
with pdfplumber.open("textMiningLabExer1.pdf") as pdf:
  # my page assigned 15-18
  # index starts at 0
  # so pages on code would be 14-17
  page1 = pdf.pages[14]
  page2 = pdf.pages[15]
  page3 = pdf.pages[16]
  page4 = pdf.pages[17]
  text1 = page1.extract_text()
  text2 = page2.extract_text()
  text3 = page3.extract_text()
  text4 = page4.extract_text()

# %% [markdown]
# ## 1) Display the sample content of your page

# %%
text = text1, text2, text3, text4
textstr = str(text)

# %%
textstr
# Out:
# "('13/01/2021  A/75/592/Add.6\\nWe will continue building the institutions of our State and consolidating them \\non the basis of the rule of law. We will continue combating international terrorism, \\nas we have done for years past. We will remain faithful to peace, justice, human and \\nnational dignity under all circumstances.\\nI salute the great Palestinian people that bravely pursues the struggle for \\nfreedom and independence. I salute our martyrs, prisoners and wounded. I salute \\nJerusalem and our people who remain steadfast in its holy sites. I salute our people \\nin the besieged Gaza Strip. I salute our people in the refugee camps everywhere. I \\nsalute all those who stand with us and with our rights from all countries, nations  \\nand organizations.\\nPeace be upon you.\\n21-00392  15/80', 'A/75/592/Add.6  13/01/2021\\nEuropean Union (see also A/75/PV.10, annex IV)\\n Address by Mr. Charles Michel, President of the European Council\\nDelivered on Friday, 25 September 2020, at the 10th meeting of the General Assembly\\n[Original: English and French; English translation provided by the \\ndelegation]\\nMister President, Mister Secretary-General, dear Heads of Delegations, Ladies \\nand Gentlemen,\\nI speak to you today on behalf of the European Union. A union founded, \\nlike the United Nations, on peaceful cooperation, human rights and fundamental \\nfreedoms. We are therefore an unwavering supporter of the United Nations. And of \\nthe international organisations to which we join forces for human progress.\\nThis is precisely how we are working with the WHO to defeat COVID-19. Like \\nthe whole world, Europe has been hard hit by the pandemic. In the European Union, \\nmore than 142,000 people have lost their lives. I salute their memory, and all the \\nCOVID-19 victims worldwide. I also pay tribute to all the healthcare professionals \\nthat have safeguarded the fabric of our societies.\\nThe crisis caused by the pandemic is unprecedented. It has exacerbated the \\nweaknesses of fragile countries, regions and populations. It has also revealed the \\nfragility of countries that thought they were strong. It has thrown us all into the same \\nsudden battle, against the same common enemy.\\nThe European Union, for its part, has been at the forefront of international \\ncooperation which has raised nearly €16 billion to finance the research and the \\ndeployment of vaccines, tests and treatments. And we are mobilized, alongside all \\nthe players involved, to ensure that these vaccines and treatments are universally \\naccessible and affordable.\\nEach nation and each leader has the duty to reflect on the best way to contribute \\nto our common objective. This is true in the fight against the current crisis, as in all \\nglobal challenges. Kofi Annan said: “To become a good citizen, start in your own \\ncommunity!” It is in this vein that I want to explain why the European Union wants to \\nbecome stronger and strategically autonomous, alongside an open market. Stronger \\nnot only for itself. But also to better contribute to a better world. The crisis has made \\nthis goal even more essential. It has awakened a new collective responsibility, to \\nbuild back better and greener…\\nLadies and Gentlemen,\\nBefore the crisis, Europe had already embarked on a path of fundamental \\ntransformation.  For  example,  by  deciding  to  become  the  first  carbon-neutral \\ncontinent by 2050. Or by adopting an ambitious digital agenda, in line with our  \\nfundamental values.\\nThis pandemic has increased our determination to transform our economies \\nand societies tenfold. €540 billion have been mobilized for urgent measures from \\nthe outset. Then, in July, the European Council decided to mobilise ambitious and \\nunprecedented financial resources: more than €1.8 trillion for the coming years, \\n16/80  21-00392', '13/01/2021  A/75/592/Add.6\\nincluding €750 billion raised via the issuance of European Union bonds, unprece ...

# %% [markdown]
# ## 2) Use the Split function to get the number of words

# %%
def remove_punc(textstr):
  # remove raw new lines
  textstr = textstr.replace("\\n", "")
  # define punctuation
  punctuations = '''!()-[]{};:"\,<>/?@#$%^-&_0123456789~*'''
  # remove punctuation from the string
  no_punct = ""
  for char in textstr:
    if char not in punctuations:
      no_punct = no_punct + char
  return no_punct

# %%
clean_text = remove_punc(textstr)

# %%
print(len(clean_text.split()))
# Out:
# 1620

# %% [markdown]
# ## 3) Use the Split function to get the number of sentences

# %%
print(len(clean_text.split(".")))
# Out:
# 106

# %% [markdown]
# ## 4) Use NLTK framework to get the number of words

# %%
# word tokenizer
def tokenizeText1(textstr):
  word_tokens = nltk.word_tokenize(textstr)
  return word_tokens

# %%
tokenized_word = tokenizeText1(clean_text)

# %%
print(len(tokenized_word))
# Out:
# 1704

# %% [markdown]
# ## 5) Use NLTK framework to get the number of sentences

# %%
# sentence tokenizer
def tokenizeText2(textstr):
  word_tokens = nltk.sent_tokenize(textstr)
  return word_tokens

# %%
tokenized_sent = tokenizeText2(clean_text)

# %%
print(len(tokenized_sent))
# Out:
# 81
