# %% [markdown]
# # 1. Tokenization using Python’s split() function

# %% [raw]
#  It returns a list of strings after breaking the given string by the specified separator. By default, split() breaks a string at each space. We can change the separator to anything

# %%
text = """Founded in 2002, SpaceX’s mission is to enable humans to become a spacefaring civilization and a multi-planet 
species by building a self-sustaining city on Mars. 
In 2008, SpaceX’s Falcon 1 became the first privately developed 
liquid-fuel launch vehicle to orbit the Earth. 
Sample here."""

# %%
# Splits at space 
strDefault=text.split()

# %%
len(strDefault)
# Out:
# 44

# %%
# Splits at period 
strPeriod =text.split('.')

# %%
len(strPeriod)
# Out:
# 4

# %%
strPeriod
# Out:
# ['Founded in 2002, SpaceX’s mission is to enable humans to become a spacefaring civilization and a multi-planet \nspecies by building a self-sustaining city on Mars',
#  ' In 2008, SpaceX’s Falcon 1 became the first privately developed \nliquid-fuel launch vehicle to orbit the Earth',
#  ' Sample here',
#  '']

# %%
import re
text = """Founded in 2002, SpaceX’s mission is to enable 
humans to become a spacefaring civilization 
and a multi-planet species by building a self-sustaining 
city on Mars. In 2008, SpaceX’s Falcon 1 became the first 
privately developed liquid-fuel launch vehicle to orbit the Earth."""
tokens = re.findall("[\w']+", text)
tokens
# Out:
# ['Founded',
#  'in',
#  '2002',
#  'SpaceX',
#  's',
#  'mission',
#  'is',
#  'to',
#  'enable',
#  'humans',
#  'to',
#  'become',
#  'a',
#  'spacefaring',
#  'civilization',
#  'and',
#  'a',
#  'multi',
#  'planet',
#  'species',
#  'by',
#  'building',
#  'a',
#  'self',
#  'sustaining',
#  'city',
#  'on',
#  'Mars',
#  'In',
#  '2008',
#  'SpaceX',
#  's',
#  'Falcon',
#  '1',
#  'became',
#  'the',
#  'first',
#  'privately',
#  'developed',
#  'liquid',
#  'fuel',
#  'launch',
#  'vehicle',
#  'to',
#  'orbit',
#  'the',
#  'Earth']

# %%
import re
text = """Founded in 2002, SpaceX’s mission is to enable 
humans to become a spacefaring civilization and a multi-planet 
species by building a self-sustaining city on, Mars. In 2008, 
SpaceX’s Falcon 1 became the first privately developed 
liquid-fuel launch vehicle to orbit the Earth."""
sentences = re.compile('[.!?] ').split(text)
print("number of sentences", len(sentences))
# Out:
# number of sentences 2

# %%
sentences
# Out:
# ['Founded in 2002, SpaceX’s mission is to enable \nhumans to become a spacefaring civilization and a multi-planet \nspecies by building a self-sustaining city on, Mars',
#  'In 2008, \nSpaceX’s Falcon 1 became the first privately developed \nliquid-fuel launch vehicle to orbit the Earth.']

# %%
from nltk.tokenize import word_tokenize 
text = """Founded in 2002, SpaceX’s mission is to enable 
humans to become a spacefaring civilization and a multi-planet 
species by building a self-sustaining city on Mars. In 2008, 
SpaceX’s Falcon 1 became the first privately developed 
liquid-fuel launch vehicle to orbit the Earth."""
word_tokenize(text)
# Out:
# ['Founded',
#  'in',
#  '2002',
#  ',',
#  'SpaceX',
#  '’',
#  's',
#  'mission',
#  'is',
#  'to',
#  'enable',
#  'humans',
#  'to',
#  'become',
#  'a',
#  'spacefaring',
#  'civilization',
#  'and',
#  'a',
#  'multi-planet',
#  'species',
#  'by',
#  'building',
#  'a',
#  'self-sustaining',
#  'city',
#  'on',
#  'Mars',
#  '.',
#  'In',
#  '2008',
#  ',',
#  'SpaceX',
#  '’',
#  's',
#  'Falcon',
#  '1',
#  'became',
#  'the',
#  'first',
#  'privately',
#  'developed',
#  'liquid-fuel',
#  'launch',
#  'vehicle',
#  'to',
#  'orbit',
#  'the',
#  'Earth',
#  '.']

# %%
from nltk.tokenize import sent_tokenize
text = """Founded in 2002, SpaceX’s mission is to enable 
humans to become! a spacefaring civilization? and a multi-planet 
species by building a self-sustaining city on Mars. In 2008, 
SpaceX’s Falcon 1 became the first privately developed 
liquid-fuel launch vehicle to orbit the Earth."""
sent_tokenize(text)
# Out:
# ['Founded in 2002, SpaceX’s mission is to enable \nhumans to become!',
#  'a spacefaring civilization?',
#  'and a multi-planet \nspecies by building a self-sustaining city on Mars.',
#  'In 2008, \nSpaceX’s Falcon 1 became the first privately developed \nliquid-fuel launch vehicle to orbit the Earth.']

# %%
import nltk

# %%
wordPunctokens = nltk.wordpunct_tokenize(text)

# %%
wordPunctokens
# Out:
# ['Founded',
#  'in',
#  '2002',
#  ',',
#  'SpaceX',
#  '’',
#  's',
#  'mission',
#  'is',
#  'to',
#  'enable',
#  'humans',
#  'to',
#  'become',
#  '!',
#  'a',
#  'spacefaring',
#  'civilization',
#  '?',
#  'and',
#  'a',
#  'multi',
#  '-',
#  'planet',
#  'species',
#  'by',
#  'building',
#  'a',
#  'self',
#  '-',
#  'sustaining',
#  'city',
#  'on',
#  'Mars',
#  '.',
#  'In',
#  '2008',
#  ',',
#  'SpaceX',
#  '’',
#  's',
#  'Falcon',
#  '1',
#  'became',
#  'the',
#  'first',
#  'privately',
#  'developed',
#  'liquid',
#  '-',
#  'fuel',
#  'launch',
#  'vehicle',
#  'to',
#  'orbit',
#  'the',
#  'Earth',
#  '.']

# %%
whiteSpaceTokens1 = nltk.WhitespaceTokenizer()
whiteSpaceWords = whiteSpaceTokens1.tokenize(text)

# %%
whiteSpaceWords
# Out:
# ['Founded',
#  'in',
#  '2002,',
#  'SpaceX’s',
#  'mission',
#  'is',
#  'to',
#  'enable',
#  'humans',
#  'to',
#  'become!',
#  'a',
#  'spacefaring',
#  'civilization?',
#  'and',
#  'a',
#  'multi-planet',
#  'species',
#  'by',
#  'building',
#  'a',
#  'self-sustaining',
#  'city',
#  'on',
#  'Mars.',
#  'In',
#  '2008,',
#  'SpaceX’s',
#  'Falcon',
#  '1',
#  'became',
#  'the',
#  'first',
#  'privately',
#  'developed',
#  'liquid-fuel',
#  'launch',
#  'vehicle',
#  'to',
#  'orbit',
#  'the',
#  'Earth.']

# %% [markdown]
# # Activity 1 - PDF file - using split function

# %%
#load pdf file
import pdfplumber
with pdfplumber.open("samplePDF_data.pdf") as pdf:
    page=pdf.pages[50]
    text=page.extract_text()

# %% [raw]
# Using split function

# %%
text
# Out:
# '13/01/2021  A/75/592/Add.1\nLithuania (see A/75/PV.5, annex XII)\nAddress  by  Mr.  Gitanas  Nausėda,  President  of  the  Republic \nof Lithuania\nDelivered on Tuesday, 22 September 2020, at the 5th meeting of the General Assembly\nMr. President,\nExcellencies, Ladies and Gentlemen,\nI am honored to address the seventy-fifth session of the United Nations \nGeneral Assembly.\nOne year ago, nobody could have imagined that this anniversary would be \nmarked by a global challenge unseen since the very foundation of this Organization. \nBut here we are, unable to meet face to face, and yet ready to make our contributions \nto solving the most pressing global issues.\nThe COVID-19 pandemic has swept through every part of the world, leaving \na devastating cost. We have paid not only in human lives, but also in a deepened \nsocial inequality.\nThat was a colossal wake-up call for multilateralism. No country can tackle \nthe pandemic and overcome the profound economic and social impact alo
# ...

# %%
sampleStr = """I am honored to address the seventy-fifth session of the United Nations
\nGeneral Assembly.\nOne year ago, nobody could have imagined that this anniversary 
would be \nmarked. by a global challenge unseen since the very foundation of this 
Organization. """

# %%
from nltk.tokenize import sent_tokenize
sent_tokenize(sampleStr)
# Out:
# ['I am honored to address the seventy-fifth session of the United Nations\n\nGeneral Assembly.',
#  'One year ago, nobody could have imagined that this anniversary \nwould be \nmarked.',
#  'by a global challenge unseen since the very foundation of this \nOrganization.']

# %%
from nltk.tokenize import word_tokenize
sampleStr2 ="""I am honored to address the seventy-fifth session of the 
               United Nations\n\nGeneral Assembly."""
word_tokenize(sampleStr2)
# Out:
# ['I',
#  'am',
#  'honored',
#  'to',
#  'address',
#  'the',
#  'seventy-fifth',
#  'session',
#  'of',
#  'the',
#  'United',
#  'Nations',
#  'General',
#  'Assembly',
#  '.']

# %%
len(text.split())
# Out:
# 447

# %%
len(text.split('.'))
# Out:
# 33

# %%
text.split('.')
# Out:
# ['13/01/2021  A/75/592/Add',
#  '1\nLithuania (see A/75/PV',
#  '5, annex XII)\nAddress  by  Mr',
#  '  Gitanas  Nausėda,  President  of  the  Republic \nof Lithuania\nDelivered on Tuesday, 22 September 2020, at the 5th meeting of the General Assembly\nMr',
#  ' President,\nExcellencies, Ladies and Gentlemen,\nI am honored to address the seventy-fifth session of the United Nations \nGeneral Assembly',
#  '\nOne year ago, nobody could have imagined that this anniversary would be \nmarked by a global challenge unseen since the very foundation of this Organization',
#  ' \nBut here we are, unable to meet face to face, and yet ready to make our contributions \nto solving the most pressing global issues',
#  '\nThe COVID-19 pandemic has swept through every part of the world, leaving \na devastating cost',
#  ' We have paid not only in human lives, but also in a deepened \nsocial inequality',
#  '\nThat was a colossal wake-up call for multilateralism',
# ...

# %%
len(text.split('\n'))
# Out:
# 43

# %%
text
# Out:
# 'A/75/592/Add.1  13/01/2021\nCurrently our two National Strategies — the first on Counter-Terrorism and \nExtremism and the second on Counter-Narcotics Trafficking are in the final phase of \nan implementation in our country.\nThe  commencement  of  cooperation  with  international  organizations  and \nregional partner institutions in elaboration of these two Strategy papers for a new \nperiod is a clear evidence of our success we have achieved in this direction.\nWe do believe it is necessary to comply with the rules and implement the \nprovisions of the relevant generally accepted treaties and conventions.\nIn  this  regard,  Tajikistan  sustains  fruitful  cooperation  with  the  relevant \nUnited Nations agencies and regional organizations, such as the Commonwealth \nof Independent States, the Shanghai Cooperation Organization and the Collective \nSecurity Treaty Organization.\nWe have also established productive bilateral cooperative relationships with \nour partner countries.\
# ...

# %% [markdown]
# # Activity 1 - using re library

# %%
tokens = re.findall("[\w']+", text)
len(tokens)
# Out:
# 434

# %%
sentences = re.compile('[.] ').split(text)
print("number of sentences", len(sentences))
# Out:
# number of sentences 2

# %% [markdown]
# # Activity 1 - using NLTK

# %%
len(word_tokenize(text))
# Out:
# 454

# %%
len(sent_tokenize(text))
# Out:
# 18

# %%
wordPunctokens2 = nltk.wordpunct_tokenize(text)

# %%
len(wordPunctokens2)
# Out:
# 482

# %%
whiteSpaceWords2 = whiteSpaceTokens1.tokenize(text)
len(whiteSpaceWords2)
# Out:
# 418

# %%
with open('extracyHTMLFileSoup.txt') as f:
    contents = f.read()
    print(contents)
# Out:
# '\n\n\r\n\tPfizer jab antibodies gone by 7 months for many: study |  ABS-CBN News\r\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nToggle navigation\n\n\n\n\n\nToggle Universal Navigation\n\n\n\n\n\n News\n\n\n\n\n\n\n\n\n\n\n\n facebook\n twitter\n youtube\n login\n\n\n\n\n\n\n\n\n\n\n\n\n\nHome\nNews\nBusiness\nEntertainment\nLife\nSports\nOverseas\nSpotlight\nWeather\nTV Patrol\nTeleradyo\nTFC\nANC\nANCX\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nHome\n\xa0>\xa0\nSpotlight\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nPfizer jab antibodies gone by 7 months for many, Delta raises COVID risks for pregnant women\n\nNancy Lapid, Reuters\n\nPosted at Oct 03 2021 11:22 AM\n\n\n\n\n\nShare\n\nFacebook\nTwitter\nLinkedIn\nViber\n\n\n\n\n\n\nA health worker prepares Pfizer COVID-19 vaccine during 
# ...

# %%
import nltk
len(nltk.word_tokenize(contents))
# Out:
# 1136

# %%
len(nltk.sent_tokenize(contents))
# Out:
# 9

# %%
myText = nltk.word_tokenize(contents)

# %%
myText
# Out:
# ["'\\n\\n\\r\\n\\tPfizer",
#  'jab',
#  'antibodies',
#  'gone',
#  'by',
#  '7',
#  'months',
#  'for',
#  'many',
#  ':',
#  'study',
#  '|',
#  'ABS-CBN',
#  'News\\r\\n\\n\\n\\n\\n\\n\\n\\n',
#  '\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\nToggle',
#  'navigation\\n\\n\\n\\n\\n\\nToggle',
#  'Universal',
#  'Navigation\\n\\n\\n\\n\\n\\n',
#  'News\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n',
#  'facebook\\n',
#  'twitter\\n',
#  'youtube\\n',
#  'login\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\nHome\\nNews\\nBusiness\\nEntertainment\\nLife\\nSports\\nOverseas\\nSpotlight\\nWeather\\nTV',
#  'Patrol\\nTeleradyo\\nTFC\\nANC\\nANCX\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\nHome\\n\\xa0',
#  '>',
# ...
